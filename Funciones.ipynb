# %% [markdown]
# Funcion en Python
#
# Autor: Andres Jacobo Urrea Ochoa
# ID: 00020552119
# Curso: Python
# En este cuaderno se estudiara el uso de funciones en Python mediante ejercicios que evidenciaran como se puede aplicar este concepto a diferentes tipos de datos, destacando la flexibilidad de estas, al usarlas con numeros, cadenas de texto, listas y tuplas.

# %% [markdown]
# Cree una función que divida la primera entrada por la segunda entrada:

# %% [markdown]
# Utilice la función <code> con </code> para la siguiente pregunta.

# %%
def con(a, b):
    return(a + b)

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para agregar números enteros o cadenas?

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para concentrar una lista o tupla?

# %% [markdown]
# Las funciones en Python ofrecen la posibilidad de favorecer la reutilizacion de codigo de forma practica y logica.
# El ejemplo de la funcion ilustra como es posible aprovechar el manejo de datos, permitiendo asi que una misma funcion trabaje con diversos tipos de datos, como numeros, cadenas, listas o tuplas.
# Sin embargo, esta flexibilidad esta condicionada a que los tipos de datos utilizados sean compatibles entre si para evitar errores en la ejecucion.
